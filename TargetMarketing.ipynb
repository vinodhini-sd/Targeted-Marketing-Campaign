# %% [markdown]
# #**Imports and Pre-requisites**

# %%
from google.colab import drive
drive.mount("/gdrive")
# %cd /gdrive/My Drive/CIS_508/Colab Notebooks/Projects/4.Target Marketing
! pwd
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/My Drive/CIS_508/Colab Notebooks/Projects/4.Target Marketing
# /gdrive/My Drive/CIS_508/Colab Notebooks/Projects/4.Target Marketing

# %%
import pandas as pd
import numpy as np
from scipy import stats
from collections import Counter

from sklearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as SMOTE_Pipeline

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

from sklearn.ensemble import GradientBoostingClassifier, StackingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import LinearSVC
from xgboost import XGBClassifier

from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import confusion_matrix, roc_auc_score

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **EDA and Data Preprocessing**

# %%
train = pd.read_csv("Train.csv")
test = pd.read_csv("Test.csv")
train.shape, test.shape
# Out:
# ((4521, 17), (45211, 17))

# %%
train.head()
# Out:
#    age          job  marital  education  ... pdays  previous poutcome   y
# 0   30   unemployed  married    primary  ...    -1         0  unknown  no
# 1   33     services  married  secondary  ...   339         4  failure  no
# 2   35   management   single   tertiary  ...   330         1  failure  no
# 3   30   management  married   tertiary  ...    -1         0  unknown  no
# 4   59  blue-collar  married  secondary  ...    -1         0  unknown  no
#
# [5 rows x 17 columns]

# %%
Xtrain = train.drop(columns = ['y']).copy()
ytrain = train['y']
Xtrain.shape, ytrain.shape
# Out:
# ((4521, 16), (4521,))

# %%
Xtrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 16 columns):
# age          4521 non-null int64
# job          4521 non-null object
# marital      4521 non-null object
# education    4521 non-null object
# default      4521 non-null object
# balance      4521 non-null int64
# housing      4521 non-null object
# loan         4521 non-null object
# contact      4521 non-null object
# day          4521 non-null int64
# month        4521 non-null object
# duration     4521 non-null int64
# campaign     4521 non-null int64
# pdays        4521 non-null int64
# previous     4521 non-null int64
# poutcome     4521 non-null object
# dtypes: int64(7), object(9)
# memory usage: 565.2+ KB

# %%
Xtrain.describe()
# Out:
#                age       balance  ...        pdays     previous
# count  4521.000000   4521.000000  ...  4521.000000  4521.000000
# mean     41.170095   1422.657819  ...    39.766645     0.542579
# std      10.576211   3009.638142  ...   100.121124     1.693562
# min      19.000000  -3313.000000  ...    -1.000000     0.000000
# 25%      33.000000     69.000000  ...    -1.000000     0.000000
# 50%      39.000000    444.000000  ...    -1.000000     0.000000
# 75%      49.000000   1480.000000  ...    -1.000000     0.000000
# max      87.000000  71188.000000  ...   871.000000    25.000000
#
# [8 rows x 7 columns]

# %%
Xtrain.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %%
cols = Xtrain.columns
num_cols = [x for x in cols if Xtrain[x].dtypes in ('int64', 'float64')]
cat_cols = [x for x in cols if Xtrain[x].dtypes not in ('int64', 'float64')]
num_cols, cat_cols
# Out:
# (['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'],
#  ['job',
#   'marital',
#   'education',
#   'default',
#   'housing',
#   'loan',
#   'contact',
#   'month',
#   'poutcome'])

# %%
len(cols), len(num_cols), len(cat_cols)
# Out:
# (16, 7, 9)

# %%
le = LabelEncoder()
temp = ytrain.copy()
ytrain = pd.DataFrame(le.fit_transform(temp), columns = ['Target'], index = temp.index)

# %%
cat_transformer = Pipeline(steps = [
                                    ('ohe', OneHotEncoder(sparse = False, handle_unknown = 'ignore'))
                                  ])
cat_transformer
# Out:
# Pipeline(memory=None,
#          steps=[('ohe',
#                  OneHotEncoder(categories='auto', drop=None,
#                                dtype=<class 'numpy.float64'>,
#                                handle_unknown='ignore', sparse=False))],
#          verbose=False)

# %%
pp = ColumnTransformer(transformers = [('cat', cat_transformer, cat_cols)],
                       remainder = 'passthrough')
pp
# Out:
# ColumnTransformer(n_jobs=None, remainder='passthrough', sparse_threshold=0.3,
#                   transformer_weights=None,
#                   transformers=[('cat',
#                                  Pipeline(memory=None,
#                                           steps=[('ohe',
#                                                   OneHotEncoder(categories='auto',
#                                                                 drop=None,
#                                                                 dtype=<class 'numpy.float64'>,
#                                                                 handle_unknown='ignore',
#                                                                 sparse=False))],
#                                           verbose=False),
#                                  ['job', 'marital', 'education', 'default',
#                                   'housing', 'loan', 'contact', 'month',
#                                   'poutcome'])],
#                   verbose=False)

# %% [markdown]
# # **SMOTE to handle imbalanced class problem**

# %%
Counter(ytrain['Target'])
# Out:
# Counter({0: 4000, 1: 521})

# %%
sm = SMOTE(ratio = 0.9, random_state = 6)

# %% [markdown]
# # **Model Building**

# %% [markdown]
# ## Model 1: XGBoost Classifier

# %%
model1 = SMOTE_Pipeline(steps = [('pp', pp),
                                 ('sm', sm),
                                 ('estimator', XGBClassifier())
                  ])

# %%
model1.fit(Xtrain, ytrain)
# Out:
# Pipeline(memory=None,
#          steps=[('pp',
#                  ColumnTransformer(n_jobs=None, remainder='passthrough',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('cat',
#                                                   Pipeline(memory=None,
#                                                            steps=[('ohe',
#                                                                    OneHotEncoder(categories='auto',
#                                                                                  drop=None,
#                                                                                  dtype=<class 'numpy.float64'>,
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse=False))],
#                                                            verbose=False),
#                                                   ['job', 'marital',
#                                                    'education', 'defa...
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, learning_rate=0.1,
#                                max_delta_step=0, max_depth=3,
#                                min_child_weight=1, missing=None,
#                                n_estimators=100, n_jobs=1, nthread=None,
#                                objective='binary:logistic', random_state=0,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                seed=None, silent=None, subsample=1,
#                                verbosity=1))],
#          verbose=False)

# %%
params1 = {
    'sm__ratio':[0.5, 0.9],
    'estimator__n_estimators': stats.randint(150, 1000),
    'estimator__learning_rate': stats.uniform(0.01, 0.6),
    'estimator__subsample': stats.uniform(0.3, 0.9),
    'estimator__max_depth': [3, 4, 5, 6, 7, 8, 9],
    'estimator__colsample_bytree': stats.uniform(0.5, 0.9),
    'estimator__min_child_weight': [1, 2, 3, 4]
    }

# %%
clf1 = RandomizedSearchCV(model1, params1, n_iter = 60, scoring = 'roc_auc', cv = 5, n_jobs = -1, random_state = 6, verbose = True)
clf1.fit(Xtrain, ytrain)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:   31.5s
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed:  7.4min
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=Pipeline(memory=None,
#                                       steps=[('pp',
#                                               ColumnTransformer(n_jobs=None,
#                                                                 remainder='passthrough',
#                                                                 sparse_threshold=0.3,
#                                                                 transformer_weights=None,
#                                                                 transformers=[('cat',
#                                                                                Pipeline(memory=None,
#                                                                                         steps=[('ohe',
#                                                                                                 OneHotEncoder(categories='auto',
#                                                                                                               drop=None,
#                                                                                                               dtype=<class 'numpy.float64'>,
#                                                                                                               handle_unknown='ignore',
#                                                                                                               sparse=False))]...
#                                         'estimator__min_child_weight': [1, 2, 3,
#                                                                         4],
#                                         'estimator__n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f06e40002b0>,
#                                         'estimator__subsample': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f06e4000978>,
#                                         'sm__ratio': [0.5, 0.9]},
#                    pre_dispatch='2*n_jobs', random_state=6, refit=True,
#                    return_train_score=False, scoring='roc_auc', verbose=True)

# %%
clf1.best_score_
# Out:
# 0.9066822115384616

# %%
clf1.best_params_
# Out:
# {'estimator__colsample_bytree': 0.756634609641987,
#  'estimator__learning_rate': 0.010511485659043997,
#  'estimator__max_depth': 7,
#  'estimator__min_child_weight': 2,
#  'estimator__n_estimators': 807,
#  'estimator__subsample': 0.7705035712356856,
#  'sm__ratio': 0.9}

# %% [markdown]
# ## Model 2: Gradient Boosting Classifier

# %%
model2 = SMOTE_Pipeline(steps = [
                                 ('pp', pp),
                                 ('sm', sm),
                                 ('estimator', GradientBoostingClassifier())
                                 ])

# %%
model2.fit(Xtrain, ytrain)
# Out:
# Pipeline(memory=None,
#          steps=[('pp',
#                  ColumnTransformer(n_jobs=None, remainder='passthrough',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('cat',
#                                                   Pipeline(memory=None,
#                                                            steps=[('ohe',
#                                                                    OneHotEncoder(categories='auto',
#                                                                                  drop=None,
#                                                                                  dtype=<class 'numpy.float64'>,
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse=False))],
#                                                            verbose=False),
#                                                   ['job', 'marital',
#                                                    'education', 'defa...
#                                             learning_rate=0.1, loss='deviance',
#                                             max_depth=3, max_features=None,
#                                             max_leaf_nodes=None,
#                                             min_impurity_decrease=0.0,
#                                             min_impurity_split=None,
#                                             min_samples_leaf=1,
#                                             min_samples_split=2,
#                                             min_weight_fraction_leaf=0.0,
#                                             n_estimators=100,
#                                             n_iter_no_change=None,
#                                             presort='deprecated',
#                                             random_state=None, subsample=1.0,
#                                             tol=0.0001, validation_fraction=0.1,
#                                             verbose=0, warm_start=False))],
#          verbose=False)

# %%
params2 = {
    'estimator__learning_rate': [0.99, 0.5, 0.1, 0.01],
    'estimator__n_estimators': [100, 200],
    'estimator__max_depth': [3, 10], 
    'estimator__min_samples_split': [5, 10],
    'estimator__subsample': [0.9, 0.5, 0.1],
    'estimator__max_features': ['sqrt', 'log2'], 
    'estimator__random_state': [6],
    'estimator__warm_start': [True],
    'estimator__verbose': [True]
}

# %%
clf2 = RandomizedSearchCV(model2, params2, cv = 5, verbose = True, random_state = 6, n_iter = 60, scoring = 'roc_auc')
clf2.fit(Xtrain, ytrain)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
#       Iter       Train Loss      OOB Improve   Remaining Time
#          1           1.1206           0.2285            0.25s
#          2           0.9001           0.2171            0.25s
#          3           0.7915           0.1240            0.25s
#          4           0.7142           0.0876            0.25s
#          5           0.6040           0.0706            0.24s
#          6           0.5960           0.0511            0.24s
#          7           0.5609           0.0309            0.23s
#          8           0.5039           0.0225            0.23s
#          9           0.5431           0.0110            0.22s
#         10           0.4657           0.0305            0.22s
#         20           0.3212           0.0000            0.18s
#         30           2.7716          -0.0129            0.16s
#         40           0.2642          -0.0219            0.13s
#         50           2.9245           0.0013            0.11s
#         60           1.5297          -0.0497            0.09s
#         70        1978.6749          -0.0251            0.06s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Streaming output truncated to the last 5000 lines.
#         40           0.2489          -0.0005            0.61s
#         50           0.2346          -0.0043            0.57s
#         60           0.2101          -0.0083            0.53s
#         70           0.2080           0.0001            0.49s
#         80           0.1946          -0.0025            0.45s
#         90           0.1799          -0.0024            0.41s
#        100           0.1787          -0.0030            0.37s
#        200      117006.9529          -0.0010            0.00s
#       Iter       Train Loss      OOB Improve   Remaining Time
#          1           1.1563           0.2183            0.75s
#          2           0.9316           0.2321            0.78s
#          3           0.7918           0.1273            0.77s
#          4           0.7334           0.0526            0.75s
#          5           0.6428           0.0800            0.76s
#          6           0.6066           0.0534            0.76s
#          7           0.5628           0.0397            0.76s
#          8           0.5124           0.0353            0.76s
#          9           0.4810           0.0189            0.75s
#         10           0.4724           0.0297            0.76s
#         20           0.3147           0.0006            0.68s
#         30           0.2749           0.0004            0.64s
#         40           0.2415          -0.0014            0.60s
#         50           0.2383          -0.0035            0.56s
#         60           0.1920          -0.0026            0.52s
#         70           0.1805          -0.0056            0.48s
#         80           0.1717           0.0002            0.44s
#         90       17313.2229          -0.0018            0.40s
#        100 2855214140177288240023143645708288.0000           0.0000            0.37s
#        200 2855214140177288240023143645708288.0000           0.0000            0.00s
#       Iter       Train Loss      OOB Improve   Remaining Time
#          1           1.1496           0.2300            0.68s
#          2           0.9361           0.2031            0.73s
#          3           0.8029           0.1238            0.74s
#          4           0.6963           0.1128            0.75s
#          5           0.6236           0.0543            0.76s
#          6           0.5817           0.0526            0.76s
#        100           0.6670           0.0036            0.66s
#        200           0.4313           0.0013            0.00s
#       Iter       Train Loss      OOB Improve   Remaining Time
#          1           1.3724           0.0126            0.85s
#          2           1.3561           0.0125            1.02s
#          3           1.3410           0.0122            1.11s
#          4           1.3245           0.0114            1.15s
#          5           1.3196           0.0119            1.18s
#          6           1.3009           0.0108            1.21s
#          7           1.2905           0.0120            1.20s
#          8           1.2805           0.0105            1.22s
#          9           1.2698           0.0108            1.26s
#         10           1.2639           0.0112            1.30s
#         20           1.1676           0.0089            1.34s
#         30           1.0730           0.0076            1.21s
#         40           0.9926           0.0077            1.14s
#         50           0.9238           0.0063            1.04s
#         60           0.8728           0.0054            0.98s
#         70           0.8176           0.0055            0.89s
#         80           0.7436           0.0039            0.81s
#         90           0.6922           0.0043            0.74s
#        100           0.6761           0.0037            0.67s
#        200           0.4392           0.0013            0.00s
#       Iter       Train Loss      OOB Improve   Remaining Time
#          1           1.3718           0.0131            0.95s
#          2           1.3580           0.0130            1.15s
#          3           1.3398           0.0127            1.18s
#          4           1.3246           0.0123            1.21s
#          5           1.3156           0.0122            1.23s
#          6           1.2985           0.0114            1.28s
#          7           1.2881           0.0117            1.31s
#          8           1.2768           0.0107            1.32s
#          9           1.2641           0.0108            1.32s
#         10           1.2621           0.0113            1.32s
#         20           1.1635           0.0100            1.30s
#         30           1.0701           0.0075            1.22s
#         40           0.9846           0.0076            1.14s
#         50           0.9180           0.0062            1.05s
#         60           0.8610           0.0058            0.97s
#         70           0.8126           0.0047            0.91s
#         80           0.7412           0.0045            0.83s
#         90           0.7014           0.0043            0.77s
#        100           0.6599           0.0040            0.69s
#        200           0.4517           0.0010            0.00s
#       Iter       Train Loss      OOB Improve   Remaining Time
#          1           1.3346           0.0517            1.17s
#          2           1.2925           0.0420            1.10s
#          3           1.2343           0.0598            1.20s
#          4           1.1828           0.0494            1.17s
#          5           1.1511           0.0368            1.14s
#          6           1.0976           0.0466            1.15s
#          7           1.0500           0.0487            1.17s
#          8           1.0163           0.0302            1.18s
#          9           0.9765           0.0382            1.17s
#         10           0.9407           0.0392            1.16s
#         20           0.7425           0.0133            1.04s
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:  4.0min finished
#         30           0.6170           0.0117            1.06s
#         40           0.5335           0.0066            0.97s
#         50           0.4732           0.0048            0.91s
#         60           0.4261           0.0044            0.84s
#         70           0.4011           0.0048            0.77s
#         80           0.3678           0.0019            0.71s
#         90           0.3478           0.0014            0.65s
#        100           0.3320           0.0027            0.59s
#        200           0.2424          -0.0003            0.00s
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=Pipeline(memory=None,
#                                       steps=[('pp',
#                                               ColumnTransformer(n_jobs=None,
#                                                                 remainder='passthrough',
#                                                                 sparse_threshold=0.3,
#                                                                 transformer_weights=None,
#                                                                 transformers=[('cat',
#                                                                                Pipeline(memory=None,
#                                                                                         steps=[('ohe',
#                                                                                                 OneHotEncoder(categories='auto',
#                                                                                                               drop=None,
#                                                                                                               dtype=<class 'numpy.float64'>,
#                                                                                                               handle_unknown='ignore',
#                                                                                                               sparse=False))]...
#                                         'estimator__max_depth': [3, 10],
#                                         'estimator__max_features': ['sqrt',
#                                                                     'log2'],
#                                         'estimator__min_samples_split': [5, 10],
#                                         'estimator__n_estimators': [100, 200],
#                                         'estimator__random_state': [6],
#                                         'estimator__subsample': [0.9, 0.5, 0.1],
#                                         'estimator__verbose': [True],
#                                         'estimator__warm_start': [True]},
#                    pre_dispatch='2*n_jobs', random_state=6, refit=True,
#                    return_train_score=False, scoring='roc_auc', verbose=True)

# %%
clf2.best_score_
# Out:
# 0.9065751144688645

# %%
clf2.best_params_
# Out:
# {'estimator__learning_rate': 0.1,
#  'estimator__max_depth': 3,
#  'estimator__max_features': 'sqrt',
#  'estimator__min_samples_split': 5,
#  'estimator__n_estimators': 200,
#  'estimator__random_state': 6,
#  'estimator__subsample': 0.9,
#  'estimator__verbose': True,
#  'estimator__warm_start': True}

# %% [markdown]
# # Model 3: MLP Classifier

# %%
model3 = SMOTE_Pipeline(steps = [
                                 ('pp', pp),
                                 ('sm', sm),
                                 ('estimator', MLPClassifier())
                                 ])

# %%
model3.fit(Xtrain, ytrain)
# Out:
# Pipeline(memory=None,
#          steps=[('pp',
#                  ColumnTransformer(n_jobs=None, remainder='passthrough',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('cat',
#                                                   Pipeline(memory=None,
#                                                            steps=[('ohe',
#                                                                    OneHotEncoder(categories='auto',
#                                                                                  drop=None,
#                                                                                  dtype=<class 'numpy.float64'>,
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse=False))],
#                                                            verbose=False),
#                                                   ['job', 'marital',
#                                                    'education', 'defa...
#                                batch_size='auto', beta_1=0.9, beta_2=0.999,
#                                early_stopping=False, epsilon=1e-08,
#                                hidden_layer_sizes=(100,),
#                                learning_rate='constant',
#                                learning_rate_init=0.001, max_fun=15000,
#                                max_iter=200, momentum=0.9, n_iter_no_change=10,
#                                nesterovs_momentum=True, power_t=0.5,
#                                random_state=None, shuffle=True, solver='adam',
#                                tol=0.0001, validation_fraction=0.1,
#                                verbose=False, warm_start=False))],
#          verbose=False)

# %%
params3 = {
    'estimator__hidden_layer_sizes': [(50,50,50), (50,100,50), (100,)],
    'estimator__activation': ['tanh', 'relu'],
    'estimator__solver': ['sgd', 'adam'],
    'estimator__alpha': [0.0001, 0.05],
    'estimator__learning_rate': ['constant','adaptive'],
}

# %%
clf3 = RandomizedSearchCV(model3, params3, cv =5, n_iter = 60, verbose = True, random_state = 6, scoring = 'roc_auc')
clf3.fit(Xtrain, ytrain)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 240 out of 240 | elapsed: 26.1min finished
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=Pipeline(memory=None,
#                                       steps=[('pp',
#                                               ColumnTransformer(n_jobs=None,
#                                                                 remainder='passthrough',
#                                                                 sparse_threshold=0.3,
#                                                                 transformer_weights=None,
#                                                                 transformers=[('cat',
#                                                                                Pipeline(memory=None,
#                                                                                         steps=[('ohe',
#                                                                                                 OneHotEncoder(categories='auto',
#                                                                                                               drop=None,
#                                                                                                               dtype=<class 'numpy.float64'>,
#                                                                                                               handle_unknown='ignore',
#                                                                                                               sparse=False))]...
#                    param_distributions={'estimator__activation': ['tanh',
#                                                                   'relu'],
#                                         'estimator__alpha': [0.0001, 0.05],
#                                         'estimator__hidden_layer_sizes': [(50,
#                                                                            50,
#                                                                            50),
#                                                                           (50,
#                                                                            100,
#                                                                            50),
#                                                                           (100,)],
#                                         'estimator__learning_rate': ['constant',
#                                                                      'adaptive'],
#                                         'estimator__solver': ['sgd', 'adam']},
#                    pre_dispatch='2*n_jobs', random_state=6, refit=True,
#                    return_train_score=False, scoring='roc_auc', verbose=True)

# %%
clf3.best_score_
# Out:
# 0.8661834706959706

# %%
clf3.best_params_
# Out:
# {'estimator__activation': 'tanh',
#  'estimator__alpha': 0.0001,
#  'estimator__hidden_layer_sizes': (100,),
#  'estimator__learning_rate': 'adaptive',
#  'estimator__solver': 'adam'}

# %% [markdown]
# # Model 4: SVC Classifier

# %%
model4 = SMOTE_Pipeline(steps = [
                                 ('pp', pp),
                                 ('sm', sm),
                                 ('estimator', LinearSVC())
])

# %%
model4.fit(Xtrain, ytrain)
# Out:
# Pipeline(memory=None,
#          steps=[('pp',
#                  ColumnTransformer(n_jobs=None, remainder='passthrough',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('cat',
#                                                   Pipeline(memory=None,
#                                                            steps=[('ohe',
#                                                                    OneHotEncoder(categories='auto',
#                                                                                  drop=None,
#                                                                                  dtype=<class 'numpy.float64'>,
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse=False))],
#                                                            verbose=False),
#                                                   ['job', 'marital',
#                                                    'education', 'defa...
#                        m_neighbors='deprecated', n_jobs=1,
#                        out_step='deprecated', random_state=6, ratio=0.9,
#                        sampling_strategy=0.9, svm_estimator='deprecated')),
#                 ('estimator',
#                  LinearSVC(C=1.0, class_weight=None, dual=True,
#                            fit_intercept=True, intercept_scaling=1,
#                            loss='squared_hinge', max_iter=1000,
#                            multi_class='ovr', penalty='l2', random_state=None,
#                            tol=0.0001, verbose=0))],
#          verbose=False)

# %%
params4 = {
    'estimator__penalty':['l1', 'l2'],
    'estimator__loss':['hinge', 'squared_hinge'],
    'estimator__C': [0.1, 1, 10, 100, 1000],
    'estimator__tol': [1, 0.1, 0.01, 0.001, 0.0001]
}

# %%
clf4 = RandomizedSearchCV(model4, params4, cv = 5, n_iter = 50, scoring = 'roc_auc', verbose = True, random_state = 6)
clf4.fit(Xtrain, ytrain)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 250 out of 250 | elapsed:  1.7min finished
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=Pipeline(memory=None,
#                                       steps=[('pp',
#                                               ColumnTransformer(n_jobs=None,
#                                                                 remainder='passthrough',
#                                                                 sparse_threshold=0.3,
#                                                                 transformer_weights=None,
#                                                                 transformers=[('cat',
#                                                                                Pipeline(memory=None,
#                                                                                         steps=[('ohe',
#                                                                                                 OneHotEncoder(categories='auto',
#                                                                                                               drop=None,
#                                                                                                               dtype=<class 'numpy.float64'>,
#                                                                                                               handle_unknown='ignore',
#                                                                                                               sparse=False))]...
#                                                         verbose=0))],
#                                       verbose=False),
#                    iid='deprecated', n_iter=50, n_jobs=None,
#                    param_distributions={'estimator__C': [0.1, 1, 10, 100, 1000],
#                                         'estimator__loss': ['hinge',
#                                                             'squared_hinge'],
#                                         'estimator__penalty': ['l1', 'l2'],
#                                         'estimator__tol': [1, 0.1, 0.01, 0.001,
#                                                            0.0001]},
#                    pre_dispatch='2*n_jobs', random_state=6, refit=True,
#                    return_train_score=False, scoring='roc_auc', verbose=True)

# %%
clf4.best_score_
# Out:
# 0.8157305860805861

# %%
clf4.best_params_
# Out:
# {'estimator__C': 10,
#  'estimator__loss': 'hinge',
#  'estimator__penalty': 'l2',
#  'estimator__tol': 0.01}

# %% [markdown]
# # **Model Selection**

# %%
test.head()
# Out:
#    age           job  marital  education  ... pdays  previous poutcome   y
# 0   58    management  married   tertiary  ...    -1         0  unknown  no
# 1   44    technician   single  secondary  ...    -1         0  unknown  no
# 2   33  entrepreneur  married  secondary  ...    -1         0  unknown  no
# 3   47   blue-collar  married    unknown  ...    -1         0  unknown  no
# 4   33       unknown   single    unknown  ...    -1         0  unknown  no
#
# [5 rows x 17 columns]

# %%
Xtest = test.drop(columns = ['y'])
ytest = test['y']
Xtest.shape, ytest.shape
# Out:
# ((45211, 16), (45211,))

# %%
temp = ytest.copy()
ytest = pd.DataFrame(le.transform(temp), columns = ['Target'], index = temp.index)
ytest.head()
# Out:
#    Target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
clf1_y_pred = clf1.predict(Xtest)
print("----------------XGBoost: Test Metrics------------------")
print("\nConfusion Matrix:\n", confusion_matrix(ytest, clf1_y_pred))
print("\nAUC:",roc_auc_score(ytest, clf1_y_pred))
# Out:
# ----------------XGBoost: Test Metrics------------------
#
# Confusion Matrix:
#  [[38668  1254]
#  [ 2782  2507]]
#
# AUC: 0.7212956975309643

# %%
clf2_y_pred = clf2.predict(Xtest)
print("----------------GBM Classifier: Test Metrics------------------")
print("\nConfusion Matrix:\n", confusion_matrix(ytest, clf2_y_pred))
print("\nAUC:",roc_auc_score(ytest, clf2_y_pred))
# Out:
# ----------------GBM Classifier: Test Metrics------------------
#
# Confusion Matrix:
#  [[38576  1346]
#  [ 2888  2401]]
#
# AUC: 0.7101226527671481

# %%
clf3_y_pred = clf3.predict(Xtest)
print("----------------XGBoost: Test Metrics------------------")
print("\nConfusion Matrix:\n", confusion_matrix(ytest, clf3_y_pred))
print("\nAUC:",roc_auc_score(ytest, clf3_y_pred))
# Out:
# ----------------XGBoost: Test Metrics------------------
#
# Confusion Matrix:
#  [[33442  6480]
#  [ 1156  4133]]
#
# AUC: 0.8095583229801421

# %%
clf4_y_pred = clf4.predict(Xtest)
print("----------------XGBoost: Test Metrics------------------")
print("\nConfusion Matrix:\n", confusion_matrix(ytest, clf4_y_pred))
print("\nAUC:",roc_auc_score(ytest, clf4_y_pred))
# Out:
# ----------------XGBoost: Test Metrics------------------
#
# Confusion Matrix:
#  [[34765  5157]
#  [ 2426  2863]]
#
# AUC: 0.7060676311812383
